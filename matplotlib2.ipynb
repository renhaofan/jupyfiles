# %%
# 散点图
import matplotlib.pyplot as plt
import numpy as np

n = 1024 # data size
# 平均值是0,方差是1
X = np.random.normal(0,1,n)
Y = np.random.normal(0,1,n)
T = np.arctan2(Y,X) # for color value  arctan(Y/X)
# 这里使用的cmap(color map),就是数值和颜色的对应表
plt.scatter(X,Y,s=75,c=T,alpha=0.5)
plt.xlim(-1.5,1.5)
# plt.xticks(()) # 可以隐藏ticks，就是坐标轴的值
plt.ylim(-1.5,1.5)
# plt.yticks(())
plt.show()

# %%
# 散点图
import matplotlib.pyplot as plt
import numpy as np

n = 1024 # data size
# 平均值是0,方差是1
X = np.random.normal(0,1,n)
Y = np.random.normal(0,1,n)
T = np.arctan2(Y,X)
plt.scatter(np.arange(5), np.arange(5))
plt.xticks(())
plt.yticks(())
plt.show()

# %%
# 柱状图
import matplotlib.pyplot as plt
import numpy as np

n = 12 
X = np.arange(n)
# (1 - X / float(n)) 用于随机生成乘积因子
Y1 = (1 - X / float(n)) * np.random.uniform(0.5,1.0,n)
Y2 = Y1
plt.bar(X,+Y1,facecolor='#9999ff',edgecolor='white')
plt.bar(X,-Y2,facecolor='#ff9999',edgecolor='white')

plt.xlim(-5,n)
plt.xticks(())
plt.ylim(-1.25,1.25)
plt.yticks(())
# zip是可以让x，y分别对应X，Y1，
for x, y in zip(X, Y1):
    # ha: horizontal alignment
    # va: vertical alignment
    plt.text(x, y + 0.05, '%.2f' % y, ha='center', va='bottom')

for x, y in zip(X, Y2):
    # ha: horizontal alignment
    # va: vertical alignment
    plt.text(x, -y - 0.05, '%.2f' % y, ha='center', va='top')


plt.show()

# %%
# 画等高线
import matplotlib.pyplot as plt
import numpy as np

def f(x,y):
    # the height function
    return (1 - x / 2 + x**5 + y**3) * np.exp(-x**2 -y**2)

n = 256
x = np.linspace(-3,3,n)
y = np.linspace(-3,3,n)
X,Y = np.meshgrid(x,y)

plt.contourf(X,Y,f(X,Y),10,alpha=0.75,cmap=plt.cm.cool)
# 可以改成plt.cm.hot

C = plt.contour(X,Y,f(X,Y),10,colors='black',linewidth=0.5)

plt.clabel(C, inline=True, fontsize=10)
plt.xticks(())
plt.yticks(())
# Out:
# /opt/anaconda3/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   s)
# ([], <a list of 0 Text yticklabel objects>)

# %%
# image 伪图片
import matplotlib.pyplot as plt 
import numpy as np

a = np.array([0.313660827978, 0.365348418405, 0.423733120134,
              0.365348418405, 0.439599930621, 0.525083754405,
              0.423733120134, 0.525083754405, 0.651536351379]).reshape(3,3)

"""
for the value of "interpolation", check this:
http://matplotlib.org/examples/images_contours_and_fields/interpolation_methods.html
for the value of "origin"= ['upper', 'lower'], check this:
http://matplotlib.org/examples/pylab_examples/image_origin.html
"""
# interpolation插值
plt.imshow(a, interpolation = 'nearest', cmap='bone', origin='upper')

# shrink 是压缩了原来长度的百分之10。如果没有就是和伪图片
plt.colorbar(shrink=0.9)


plt.xticks(())
plt.yticks(())
plt.show()

# %%
# 3D图
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D


fig = plt.figure()
ax = Axes3D(fig)

# %%
# 3D图
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D


fig = plt.figure()
ax = Axes3D(fig)

# X,Y value
X = np.arange(-4,4,0.25)
Y = np.arange(-4,4,0.25)
X,Y = np.meshgrid(X,Y)
R = np.sqrt(X ** 2 + Y ** 2)
# height value
Z = np.sin(R)

ax.plot_surface(X,Y,Z,rstride=1,cstride=1, cmap='rainbow')
ax.contourf(X, Y, Z, zdir='x', offset=-4, cmap='rainbow')
"""
============= ================================================
        Argument      Description
        ============= ================================================
        *X*, *Y*, *Z* Data values as 2D arrays
        *rstride*     Array row stride (step size), defaults to 10
        *cstride*     Array column stride (step size), defaults to 10
        *color*       Color of the surface patches
        *cmap*        A colormap for the surface patches.
        *facecolors*  Face colors for the individual patches
        *norm*        An instance of Normalize to map values to colors
        *vmin*        Minimum value to map
        *vmax*        Maximum value to map
        *shade*       Whether to shade the facecolors
        ============= ================================================
"""
"""
==========  ================================================
        Argument    Description
        ==========  ================================================
        *X*, *Y*,   Data values as numpy.arrays
        *Z*
        *zdir*      The direction to use: x, y or z (default)
        *offset*    If specified plot a projection of the filled contour
                    on this position in plane normal to zdir
        ==========  ================================================
"""
ax.set_zlim(-2, 2)
plt.show()
